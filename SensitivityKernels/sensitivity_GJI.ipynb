# %% [markdown]
# This notebook demonstrates how to get sensitivity kernel with a input velocity model.

# %%
import numpy as np
import disba 
import matplotlib.pyplot as plt

# %% [markdown]
# The demo model but change scale.<br>
#
# ![image.png](attachment:image.png)
#
# [figure 4b](
# https://oup.silverchair-cdn.com/oup/backfile/Content_public/Journal/gji/219/3/10.1093_gji_ggz391/1/ggz391fig4.jpeg?Expires=1733192492&Signature=ti8Z~3TBFnOcCzcsYvpvOT--6CI9OvmDZVMuMIzmLy~Nt2ULz1T26nOIL03ZBIDW-ze3i5pgco7VJjwIrqISiu-arxKTtWEgvrjKIaWrcuIKkBOsEtAisX8IDgmGb~eanZlOxsoyXAGzqOt0UUh8r2-YozN3V6xhAvGU7Ygtvhx~4oWXkGLGn-j2GlcxE-kaN~48f1apLsz-uQrDs3~f1xgX~xShP5AlxjEzijnS0pSQtxGibfIzRwBr2j~vqzxzCDA2nf1JWsNBfMEnXhmQfLHNH5neq2oZCdbvegoxuDs10zs4ltUJvAvTZF4-QZVP0ejQ~otN4Lx8g5qmdHJz4g__&Key-Pair-Id=APKAIE5G5CRDK6RD3PGA)
# from this paper: https://academic.oup.com/gji/article/219/3/1636/5558237

# %%
# Velocity model
# thickness, Vp, Vs, density
# km, km/s, km/s, g/cm3
velocity_model = np.array([
[0.004 , 0.35, 0.15, 2.0] ,
[0.004 , 0.35, 0.15, 2.0] ,
[0.004 , 0.35, 0.15, 2.0] ,
[0.004 , 0.35, 0.15, 2.0] ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 0.8, 0.3, 2.0]   ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 , 1.9, 0.25, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
[0.004 ,  1.9, 0.90, 2.0]  ,
])

# Periods must be sorted starting with low periods
t = np.logspace(-2, 1, 100)

# Compute the 3 first Rayleigh- and Love- wave modal dispersion curves
# Fundamental mode corresponds to mode 0
pd = disba.PhaseDispersion(*velocity_model.T)
cpr = [pd(t, mode=i, wave="rayleigh") for i in range(1)]
cpl = [pd(t, mode=i, wave="love") for i in range(1)]

# pd returns a namedtuple (period, velocity, mode, wave, type)

# %%
print(cpr)
# Out:
# [DispersionCurve(period=array([ 0.01      ,  0.01072267,  0.01149757,  0.01232847,  0.01321941,
#         0.01417474,  0.01519911,  0.01629751,  0.01747528,  0.01873817,
#         0.02009233,  0.02154435,  0.0231013 ,  0.02477076,  0.02656088,
#         0.02848036,  0.03053856,  0.03274549,  0.03511192,  0.03764936,
#         0.04037017,  0.04328761,  0.04641589,  0.04977024,  0.05336699,
#         0.05722368,  0.06135907,  0.06579332,  0.07054802,  0.07564633,
#         0.08111308,  0.0869749 ,  0.09326033,  0.1       ,  0.10722672,
#         0.1149757 ,  0.12328467,  0.13219411,  0.14174742,  0.15199111,
#         0.16297508,  0.17475284,  0.18738174,  0.2009233 ,  0.21544347,
#         0.23101297,  0.24770764,  0.26560878,  0.28480359,  0.30538555,
#         0.32745492,  0.35111917,  0.37649358,  0.40370173,  0.43287613,
#         0.46415888,  0.49770236,  0.53366992,  0.57223677,  0.61359073,
#         0.65793322,  0.70548023,  0.75646333,  0.81113083,  0.869749  ,
# ...

# %%
from disba import EigenFunction

eigf = EigenFunction(*velocity_model.T)
eigr = eigf(1.0, mode=0, wave="rayleigh")
eigl = eigf(1.0, mode=0, wave="love")

# eigf returns a namedtuple
#  - (depth, ur, uz, tz, tr, period, mode) for Rayleigh-wave
#  - (depth, uu, tt, period, mode) for Love-wave

# %%
from disba import PhaseSensitivity

ps = PhaseSensitivity(*velocity_model.T)
parameters = ["thickness", "velocity_p", "velocity_s", "density"]
skr = [ps(0.5, mode=0, wave="rayleigh", parameter=parameter) for parameter in parameters]
skl = [ps(0.5, mode=0, wave="love", parameter=parameter) for parameter in parameters]

# ps returns a namedtuple (depth, kernel, period, velocity, mode,wave, type, parameter)

# %%
ps = PhaseSensitivity(*velocity_model.T)
parameters = ["thickness", "velocity_p", "velocity_s", "density"]
skr4 = [ps(0.25, mode=0, wave="rayleigh", parameter=parameter) for parameter in parameters]
skl4 = [ps(0.25, mode=0, wave="love", parameter=parameter) for parameter in parameters]

# ps

# %%
ps = PhaseSensitivity(*velocity_model.T)
parameters = ["thickness", "velocity_p", "velocity_s", "density"]
skr8 = [ps(0.125, mode=0, wave="rayleigh", parameter=parameter) for parameter in parameters]
skl8 = [ps(0.125, mode=0, wave="love", parameter=parameter) for parameter in parameters]

# ps

# %%
#print(velocity_model.T[:])
dep=np.zeros(len(velocity_model))
tmp=0.

for k in range(1,len(velocity_model)):
    dep[k]=tmp+velocity_model.T[0][k]
    tmp=dep[k]
    #print(k, dep[k],tmp)

# %%
fig,ax = plt.subplots(1,3, figsize=(12,5))
ax[0].set_ylim(120,0)
ax[1].set_ylim(120,0)
ax[2].set_ylim(120,0)


k=2
ax[0].set_title("Velocity model")
ax[0].set_xlabel("Velocity (km/s)")
ax[0].set_ylabel("Depth (m)")
ax[0].plot(velocity_model.T[1],dep*1000,label="Vp")
ax[0].plot(velocity_model.T[2],dep*1000,label="Vs")
ax[1].plot(skr[k].kernel,  skr[k].depth *1000, label=str(1/skr[k].period)+" Hz" )
ax[1].plot(skr4[k].kernel, skr4[k].depth*1000, label=str(1/skr4[k].period)+" Hz" )
ax[1].plot(skr8[k].kernel, skr8[k].depth*1000, label=str(1/skr8[k].period)+" Hz" )
ax[1].set_xlabel("Sensitivity")
ax[1].set_title("Rayleigh wave sensitivity kernel")

ax[2].plot(skl[k].kernel,  skl[k].depth *1000, label=str(1/skl[k].period)+" Hz" )
ax[2].plot(skl4[k].kernel, skl4[k].depth*1000, label=str(1/skl4[k].period)+" Hz" )
ax[2].plot(skl8[k].kernel, skl8[k].depth*1000, label=str(1/skl8[k].period)+" Hz" )
ax[2].set_xlabel("Sensitivity")
ax[2].set_title("Love wave sensitivity kernel")

ax[0].legend()
ax[1].legend()
ax[2].grid(True)
ax[2].legend()
ax[1].grid(True)
ax[0].grid(True)
